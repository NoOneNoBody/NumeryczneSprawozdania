# %%
#Zadanie 1
import math
k = 1240 * math.sqrt(7)
m = 4467
l = 2j
d = k+m
c = d+l
print(type(k))
print(type(m))
print(type(l))
print(type(d))
print(type(c))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'complex'>
# <class 'float'>
# <class 'complex'>

# %%
#Zadanie 2
print(d)
print(round(d,3))
print(round(d,20))
# Out:
# 7747.731625720093
# 7747.732
# 7747.731625720093

# %%
# Zadanie 3
r = 17
h = 33
S = 2*math.pi*(r**2) + 2*math.pi*r*h
print(S)
# Out:
# 5340.707511102648

# %%
#Zadanie 4
"""
Komentarze
"""
# Out:
# '\nKomentarze\n'

# %%
#Zadanie 5
"""
jeśli za duże zmienne pojawia się overflow error
"""
x1 = 1
t = 2
r = 3
B = ((x1 + r)/(r * math.sin(2*x1) + 3.3456)) * x1**(t*r)
print(B)
# Out:
# 0.6585996680785801

# %%
#Zadanie 6
import numpy as np
a = math.sqrt(2)
M = np.matrix([[a,1,-a],[0,1,1],[-a,a,1]])
print(M)

# %%
#Zadanie 7
print(M[0,0])
print(M[2,1])
print(M[2,2])
w1 = M[:,2]
w2 = M[1,:]
print(w1)
print(w2)
# Out:
# [[ 1.41421356  1.         -1.41421356]
#  [ 0.          1.          1.        ]
#  [-1.41421356  1.41421356  1.        ]]
# 1.4142135623730951
# 1.4142135623730951
# 1.0
# [[-1.41421356]
#  [ 1.        ]
#  [ 1.        ]]
# [[0. 1. 1.]]

# %%
#Zadanie 8
import numpy as np
coeffs = [1,-7,3,43,-28,-60]
roots = np.roots(coeffs)
print(roots)
# Out:
# [ 5.  3.  2. -2. -1.]

# %%
#Zadanie 9
import numpy as np
a = np.arange(0.3, 6., 1.5)
b = np.linspace(0.3, 6., 5)
print(a)
print(b)
# Out:
# [0.3 1.8 3.3 4.8]
# [0.3   1.725 3.15  4.575 6.   ]

# %%
#Zadanie 10
import matplotlib.pyplot as plt
import numpy as np
def func(x):
    return (x**3 - 3*x)
x = np.linspace(-1,1) 
y = func(x)
plt.subplot(111)
plt.plot(x, y)
plt.show()
x = np.linspace(-5,5)
plt.subplot(111)
plt.plot(x, y)
plt.show()
x = np.linspace(0,5)
plt.subplot(111)
plt.plot(x, y)
plt.show()

# %%
# Zadanie 11
import matplotlib.pyplot as plt
import numpy as np

def funcQ(m,v):
    return (m*(v**2))/(2*36*36*10)

m = 2500
v = 60
#Q1 = (m*(v**2))/(2*36)
#1 cal = 4,1868 J
Q = funcQ(m,v)
K = Q/4186.8
print(Q,"J")#wynik w dżulach
print(K, "kcal")#wynik w kilokaloriach

m = 3000
x = np.linspace(200,0)
y = funcQ(m,x)
plt.subplot(111)
plt.xlim(200,0)
plt.plot(x, y)
plt.show()
plt.subplot(111)
plt.xlim(200,0)
plt.semilogy(x,y)
plt.show()
# Out:
# 347.22222222222223 J
# 0.08293260299565831 kcal
